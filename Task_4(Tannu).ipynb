# %% [markdown]
# # Cv Programme

# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread("/content/d3.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=736x1308>
